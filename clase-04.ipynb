# %% [markdown]
# > Aprovechen que hoy corto 19:40
# # Repaso de funciones 🐍
#
# ### ¿Es primo el numero?

# %%
# SOLID -> Single responsability
# Crear una función llamada "es_primo" que reciba un número positivo como parámetro -> devolver True / False

# %%
def es_primo(n):
    n_entero = int(n)
    # Solo puede dividirse por 1 y por si mismo
    # El número 1 no es primo
    
    # debería lanzar una exception
    # early return
    if n_entero < 0:
        return "Solo aceptamos numeros positivos o cero"
    if n_entero <= 1:
        return False
    for i in range(2, n_entero):
        if n_entero % i == 0: # si esto sucede, tiene divisores => NO es primo
            return False
    # si llegamos hasta acá
    return True
    
    # la unica condición que queda es que sea mayor a cero

# %%
es_primo(2)
# Out:
# True

# %%
# 17

# 17 % 2 # si el resto es 1... no es exacta 
6 % 3 == 0
# Out:
# True

# %% [markdown]
# ### Diccionarios
# Estructura de datos que almacena clave-valor

# %%
franco = {
    "nombre": "Franco Di Leo",
    "edad": 31,
    "profesion": "Desarrollador",
    "mascotas": [
        "Amazonas", "Perla"
    ]
}

type(franco)
# Out:
# dict

# %%
print(f"{franco['nombre']} tiene {len(franco['mascotas'])} mascotas, la última de la lista es {franco['mascotas'][-1]}")
# Out:
# Franco Di Leo tiene 2 mascotas, la última de la lista es Perla

# %%
# Nombre y tipo de la última mascota de la lista mas_de_fran

# %%
mas_de_fran = {
    "nombre": "Franco Di Leo",
    "edad": 31,
    "profesion": "Desarrollador",
    "mascotas": [
       {
           "tipo": "Perro",
           "nombre": "Amazonas",
           "edad": 4
       },
        {
           "tipo": "Tortuga",
           "nombre": "squirtle",
           "edad": 1
       },
    ]
}

# %%
mas_de_fran
# Out:
# {'nombre': 'Franco Di Leo',
#  'edad': 31,
#  'profesion': 'Desarrollador',
#  'mascotas': [{'tipo': 'Perro', 'nombre': 'Amazonas', 'edad': 4},
#   {'tipo': 'Tortuga', 'nombre': 'squirtle', 'edad': 1}]}

# %%
mas_de_fran["mascotas"][-1]["nombre"] + " "+  mas_de_fran["mascotas"][-1]["tipo"]
# Out:
# 'squirtle Tortuga'

# %%
print(mas_de_fran["mascotas"][-1]["nombre"])
# Out:
# squirtle

# %%
alex = {
    "nombre": "Alexander Del Risco",
    "apodo": False,
    "hobbies": ["Futbol", "Lectura", "Canto"],
    "herramientas_laborales" : [
        {
            "nombre": "Power Apps",
            "nivel": 10
        },
        {
            "nombre": "Power Automate",
            "nivel": 7
        },
    ],
    "idiomas": ["Español", "Inglés"]
}

# %%
# como mostramos el nombre de TODAS las herramientas laborales que maneja Alex?
print(alex["nombre"], "maneja: ")
for herramienta in alex["herramientas_laborales"]:
    print("- ",herramienta["nombre"])
# Out:
# Alexander Del Risco maneja:
# -  Power Apps
# -  Power Automate

# %% [markdown]
# ### Pandas / Polars
# Pandas es una librería de Python especializada en el manejo y análisis de estructuras de datos.
#
# Las principales características de esta librería son:
#
# - Define nuevas estructuras de datos basadas en los arrays de la librería NumPy pero con nuevas funcionalidades.
# - Permite leer y escribir fácilmente ficheros en formato CSV, Excel y bases de datos SQL.
# - Permite acceder a los datos mediante índices o nombres para filas y columnas.
# - Ofrece métodos para reordenar, dividir y combinar conjuntos de datos.
# - Permite trabajar con series temporales.
# - Realiza todas estas operaciones de manera muy eficiente.

# %%
import pandas as pd # alias -> forma abreviada de llamar a nuestra libreria

# %%
# pip -> gestor de paquetes

# %%
# pip install seaborn
# pip install numpy
# pip install pandas

# %%
# importar datos

# %%
df = pd.read_csv("titanic.csv")# DataFrame -> tabla

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# Imprimir los primeros 5 registros
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Imprimir los primeros 5 registros
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 886          887         0       2                    Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss Margaret Edith
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape # (filas, columnas)
# Out:
# (891, 12)

# %%
# Información resumida de mi dataset (columna, count no-null items, tipo de dato)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# estadística numericas 
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Filtrar
df[["Sex","Age","Survived"]]
# Out:
#         Sex   Age  Survived
# 0      male  22.0         0
# 1    female  38.0         1
# 2    female  26.0         1
# 3    female  35.0         1
# 4      male  35.0         0
# ..      ...   ...       ...
# 886    male  27.0         0
# 887  female  19.0         1
# 888  female   NaN         0
# 889    male  26.0         1
# 890    male  32.0         0
#
# [891 rows x 3 columns]

# %%
[1,2,3] == 2
# Out:
# False

# %%
df_survived = df[df["Survived"] == 1] # Estamos generando un dataframe EN MEMORIA (VIRTUAL) las personas que sobrevivieron

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C

# %%
df_survived_gt20 = df[(df["Survived"] == 1) & (df["Age"] > 20)]

# %%
len(df_survived_gt20)
# Out:
# 208

# %%
# Not null & not a number

# %%
df.isnull().sum() # cantidad de datos nulos agrupados por columna
df.notnull().sum() # cantidad de datos no nulos agrupados por columna
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# hacer una función que clasifique el riesgo de una persona del titanic
# Si es clase 1 y menor o = a 15 años -> bajo
# Si es clase 3 y tiene más de 60 años -> riesgo alto
# Sino (else) riesgo medio

# %%
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
def clasificar_riesgo(pasajero):
    print(pasajero)
    edad = pasajero["Age"]
    clase = pasajero["Pclass"]
    
    if edad <= 15 and clase == 1:
        return "bajo"
    if edad > 60 and clase == 3:
        return "alto"
    return "medio"

# %%
# df[0]
df.iloc[4] # index location. Devuelve el elemento 4 del dataframe
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 4, dtype: object

# %%
persona = df.iloc[297] # elijo a la primera persona del dataframe
clasificar_riesgo(persona)
# Out:
# PassengerId                            298
# Survived                                 0
# Pclass                                   1
# Name           Allison, Miss Helen Loraine
# Sex                                 female
# Age                                    2.0
# SibSp                                    1
# Parch                                    2
# Ticket                              113781
# Fare                                151.55
# Cabin                              C22 C26
# Embarked                                 S
# Name: 297, dtype: object
# 'bajo'

# %%
df[(df["Age"] <= 15) & (df["Pclass"] == 1)]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 297          298         0       1         Allison, Miss Helen Loraine
# 305          306         1       1       Allison, Master Hudson Trevor
# 435          436         1       1            Carter, Miss Lucile Polk
# 445          446         1       1            Dodge, Master Washington
# 689          690         1       1    Madill, Miss Georgette Alexandra
# 802          803         1       1  Carter, Master William Thornton II
#
#         Sex    Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 297  female   2.00      1      2  113781  151.5500  C22 C26        S
# 305    male   0.92      1      2  113781  151.5500  C22 C26        S
# 435  female  14.00      1      2  113760  120.0000  B96 B98        S
# 445    male   4.00      0      2   33638   81.8583      A34        S
# 689  female  15.00      0      1   24160  211.3375       B5        S
# 802    male  11.00      1      2  113760  120.0000  B96 B98        S
